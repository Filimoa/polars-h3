# %% [markdown]
# ### Note
#
# You can find the google colab version of this notebook [here](https://drive.google.com/file/d/18jIVEbE_1QbwTbHdMqj0AVqguf2Vrtrc/view?usp=sharing).

# %%
# !pip install polars polars-h3 matplotlib folium

# %%
import polars as pl
import polars_h3 as plh3

# !mkdir -p sample-data
# !wget https://sergey-filimonov.nyc3.cdn.digitaloceanspaces.com/polars-h3/sample-data/sample-telematics-data.parquet -O sample-data/sample-telematics-data.parquet
# Out:
# --2025-07-17 22:31:05--  https://sergey-filimonov.nyc3.cdn.digitaloceanspaces.com/polars-h3/sample-data/sample-telematics-data.parquet
# Resolving sergey-filimonov.nyc3.cdn.digitaloceanspaces.com (sergey-filimonov.nyc3.cdn.digitaloceanspaces.com)... 172.64.145.29, 104.18.42.227
# Connecting to sergey-filimonov.nyc3.cdn.digitaloceanspaces.com (sergey-filimonov.nyc3.cdn.digitaloceanspaces.com)|172.64.145.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67718 (66K) [text/plain]
# Saving to: ‘sample-data/sample-telematics-data.parquet’
#
# sample-data/sample- 100%[===================>]  66.13K  --.-KB/s    in 0.002s
#
# 2025-07-17 22:31:05 (33.1 MB/s) - ‘sample-data/sample-telematics-data.parquet’ saved [67718/67718]

# %% [markdown]
# # Advanced Notebooks: Working with Telematics Data 🚗
#
# When working with telematics data, you'll often see it formatted with a GPS coordinate along of a timestamp. This can be challenging to analyze - we'll explore a case study on how h3 can be used to help.
#
# ### Case Study: Analyzing Delivery Route Efficiency 🚚
# Logistics and delivery companies often want to know where their drivers are spending the most time. By mapping telematics data to H3 hexes, they can identify slow-moving segments of their delivery routes. If certain hex cells consistently lead to delays, these areas can be flagged for route re-planning.
#
# Let's imagine we're tasked with finding how long our users are spending in a given area, given the following data that we've collected from their vehicles.

# %%
# Real world telematics data tends to be messy, so we're going to take a small fraction of the available data to work with.

df = pl.read_parquet(
    "./sample-data/sample-telematics-data.parquet",
).sample(fraction=0.15, seed=42)

df.head()
# Out:
# shape: (5, 4)
# ┌───────────┬─────────────┬────────────────────────────┬─────────┐
# │ lat       ┆ long        ┆ timestamp                  ┆ user_id │
# │ ---       ┆ ---         ┆ ---                        ┆ ---     │
# │ f64       ┆ f64         ┆ datetime[μs]               ┆ str     │
# ╞═══════════╪═════════════╪════════════════════════════╪═════════╡
# │ 39.984222 ┆ -105.001856 ┆ 2024-12-16 03:19:57.328863 ┆ sergey  │
# │ 39.842133 ┆ -104.678345 ┆ 2024-12-16 03:46:01.814648 ┆ sergey  │
# │ 39.837963 ┆ -104.687351 ┆ 2024-12-16 03:41:59.725038 ┆ sergey  │
# │ 39.698351 ┆ -105.717406 ┆ 2024-12-16 07:23:38.309796 ┆ sergey  │
# │ 39.745424 ┆ -105.436932 ┆ 2024-12-16 07:00:56.919874 ┆ sergey  │
# └───────────┴─────────────┴────────────────────────────┴─────────┘

# %% [markdown]
# ## Let's try visualizing the data and see what we're working with.

# %%
# Make sure you have volume and mapplotlib installed to use the graphing functions
# !uv pip install folium matplotlib

# %%
# IMPORTANT: Notice all the gaps in the data -
# There's no particular reason to use hexes to visualize the points, but it's a good exercise.

plotting_df = df.with_columns(
    [plh3.latlng_to_cell(pl.col("lat"), pl.col("long"), 9).alias("hex9")]
)

plh3.graphing.plot_hex_outlines(plotting_df, hex_id_col="hex9")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c81feff18379d101304ded2e4384d545 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c81feff18379d101304ded2e4384d545&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c81feff18379d101304ded2e4384d545 = L.map(
#                 &quot;map_c81feff18379d101304ded2e4384d545&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1477867b9d1dd80ff5667243afbc25c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1477867b9d1dd80ff5667243afbc25c.addTo(map_c81feff18379d101304ded2e4384d545);
#
#
#             var polygon_9ef43abbc44c29f5fea6f076b969430c = L.polygon(
#                 [[39.98196365729831, -105.00157196874046], [39.983466756868715, -105.0001531417749], [39.98514551632928, -105.0012214682897], [39.98532116553107, -105.00370867811036], [39.98381804759794, -105.00512748563257], [39.982139298826084, -105.0040591027809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c81feff18379d101304ded2e4384d545);
#
#
#             var polygon_059f7e3b3482482aeb84dcc5f54dde21 = L.polygon(
#                 [[39.84000814080234, -104.67930261022748], [39.84150914734406, -104.67788169961197], [39.843192629074316, -104.67894272532916], [39.843375093975155, -104.68142471874515], [39.84187406889458, -104.68284561115193], [39.84019059745236, -104.68178452835484]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c81feff18379d101304ded2e4384d545);
#
#
#             var polygon_a34acde2c4244f30a3e55fff4ddf9f27 = L.polygon(
#                 [[39.8373707404228, -104.68710805692125], [39.83887189211505, -104.68568728024016], [39.84055535326418, -104.68674842010482], [39.840737652423236, -104.68923039370925], [39.83923648219484, -104.69065115215395], [39.837553031343866, -104.689589955234]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c81feff18379d101304ded2e4384d545);
#
#
#             var polygon_3df71916bbb012b38512db886528f74d = L.polygon(
#                 [[39.69628819870536, -105.71535314785056], [39.69780501700895, -105.71394752922085], [39.69948235020917, -105.71502554116883], [39.699642853511484, -105.71750922574941], [39.698126017122945, -105.71891482244516], [39.69644869551734, -105.7178367564977]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c81feff18379d101304ded2e4384d545);
#
#
#             var polygon_560faac15ebc44bb2244c66fe944869a = L.polygon(
#                 [[39.7438403851671, -105.43659

# %% [markdown]
# ### 🌐 Attaching trip ids to the data
# One of the first challenges when getting an export of telematics data can actually be figuring out how to attach trip ids to the data.
#
# Trip IDs are essential because they segment telematics data into distinct trips, making analysis possible. Without them, the data is an unstructured stream of GPS points, and you can't identify where trips start or end, measure time spent in specific areas, or tie data to real-world events like geofencing alerts or delivery stops.

# %%
FIFTEEN_MINUTES = 15 * 60
hex_col = "hex9"


def attach_trip_ids(df: pl.DataFrame, partition_columns: list[str]) -> pl.DataFrame:
    REQUIRED_COLUMNS = partition_columns + ["timestamp", "lat", "long"]

    return (
        df.unique()
        .select(REQUIRED_COLUMNS)
        .sort(partition_columns + ["timestamp"])
        .with_columns(
            [
                (pl.col("timestamp").diff().dt.total_milliseconds() / pl.lit(1000))
                .over(partition_columns)
                .alias("elapsed_seconds"),
                pl.col("lat").round(5),  # 1 meter precision
                pl.col("long").round(5),  # 1 meter precision
            ]
        )
        .with_columns(
            (
                (pl.col("elapsed_seconds") > FIFTEEN_MINUTES)
                .fill_null(False)
                .cast(pl.Boolean)
                .cum_sum()
                .alias("user_trip_id")
            ).over(partition_columns)  # Creating trip ids within each group
        )
        .with_columns(
            pl.concat_str(
                [pl.col(col).cast(pl.Utf8) for col in partition_columns]
                + [pl.col("user_trip_id").cast(pl.Utf8)],
                separator="-",
            ).alias("trip_id")  # global trip id
        )
        .drop(["user_trip_id"])
        .sort(partition_columns + ["timestamp"])
        .with_columns(
            [
                plh3.latlng_to_cell(
                    pl.col("lat"), pl.col("long"), 9, return_dtype=pl.Utf8
                ).alias(hex_col)
            ]
        )
    )


trips = attach_trip_ids(df, ["user_id"])
display(trips.head())

# Looks like we're working with 2 distinct trips.
display(trips["trip_id"].value_counts())
# Out:
# shape: (5, 7)
# ┌─────────┬─────────────────┬──────────┬────────────┬─────────────────┬──────────┬─────────────────┐
# │ user_id ┆ timestamp       ┆ lat      ┆ long       ┆ elapsed_seconds ┆ trip_id  ┆ hex9            │
# │ ---     ┆ ---             ┆ ---      ┆ ---        ┆ ---             ┆ ---      ┆ ---             │
# │ str     ┆ datetime[μs]    ┆ f64      ┆ f64        ┆ f64             ┆ str      ┆ str             │
# ╞═════════╪═════════════════╪══════════╪════════════╪═════════════════╪══════════╪═════════════════╡
# │ sergey  ┆ 2024-12-16      ┆ 40.0189  ┆ -105.27893 ┆ null            ┆ sergey-0 ┆ 892681a306fffff │
# │         ┆ 02:51:11.963989 ┆          ┆            ┆                 ┆          ┆                 │
# │ sergey  ┆ 2024-12-16      ┆ 40.01919 ┆ -105.27903 ┆ 26.207          ┆ sergey-0 ┆ 892681a306fffff │
# │         ┆ 02:51:38.171209 ┆          ┆            ┆                 ┆          ┆                 │
# │ sergey  ┆ 2024-12-16      ┆ 40.01686 ┆ -105.27964 ┆ 80.42           ┆ sergey-0 ┆ 892681a33d3ffff │
# │         ┆ 02:52:58.591218 ┆          ┆            ┆                 ┆          ┆                 │
# │ sergey  ┆ 2024-12-16      ┆ 40.01572 ┆ -105.27923 ┆ 46.551          ┆ sergey-0 ┆ 892681a33d7ffff │
# │         ┆ 02:53:45.142662 ┆          ┆            ┆                 ┆          ┆                 │
# │ sergey  ┆ 2024-12-16      ┆ 40.01517 ┆ -105.27904 ┆ 7.758           ┆ sergey-0 ┆ 892681a33d7ffff │
# │         ┆ 02:53:52.901236 ┆          ┆            ┆                 ┆          ┆                 │
# └─────────┴─────────────────┴──────────┴────────────┴─────────────────┴──────────┴─────────────────┘
# shape: (2, 2)
# ┌──────────┬───────┐
# │ trip_id  ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ sergey-0 ┆ 188   │
# │ sergey-1 ┆ 422   │
# └──────────┴───────┘

# %% [markdown]
# ### We now have a better idea of how long the user spent in each hexagon.

# %%
plh3.graphing.plot_hex_fills(
    trips.drop_nulls(), hex_id_col=hex_col, metric_col="elapsed_seconds"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7048f0ce608a795fc58949598e73d0c7 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7048f0ce608a795fc58949598e73d0c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7048f0ce608a795fc58949598e73d0c7 = L.map(
#                 &quot;map_7048f0ce608a795fc58949598e73d0c7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99721daf98dd31cae2bdfb6f86a3df38 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99721daf98dd31cae2bdfb6f86a3df38.addTo(map_7048f0ce608a795fc58949598e73d0c7);
#
#
#             var polygon_d034a09d87ff061922e581f495082f93 = L.polygon(
#                 [[40.017049457282525, -105.2760371821852], [40.018555636775524, -105.27462138937283], [40.02023163980317, -105.2756950016612], [40.02040145230899, -105.27818446236408], [40.018895254588266, -105.27960023471259], [40.017219262589784, -105.27852656682553]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#9310a1&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#9310a1&quot;, &quot;fillOpacity&quot;: 0.7244531573741965, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7048f0ce608a795fc58949598e73d0c7);
#
#
#             polygon_d034a09d87ff061922e581f495082f93.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a306fffff&lt;br&gt;elapsed_seconds: 26.207
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_32855496156f826b04c87352614164a4 = L.polygon(
#                 [[40.01571301103724, -105.27994229053606], [40.017219262589784, -105.27852656682553], [40.018895254588266, -105.27960023471259], [40.01906498400045, -105.28208968189972], [40.01755871422176, -105.28350538513264], [40.01588273325735, -105.28243166165943]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#bb3586&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bb3586&quot;, &quot;fillOpacity&quot;: 0.7765039093423749, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7048f0ce608a795fc58949598e73d0c7);
#
#
#             polygon_32855496156f826b04c87352614164a4.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a33d3ffff&lt;br&gt;elapsed_seconds: 80.42
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_cb201a835485961a0b59954287357b35 = L.polygon(
#                 [[40.01386717429727, -105.27637934149125], [40.01537340762154, -105.2749635973169], [40.017049457282525, -105.2760371821852], [40.017219262589784, -105.27852656682553], [40.01571301103724, -105.27994229053606], [40.014036972406046, -105.2788686500735]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a92395&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#a92395&quot;, &quot;fillOpacity&quot;: 0.7509655037212446, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_7048f0ce608a795fc58949598e73d0c7);
#
#
#             polygon_cb201a835485961a0b59954287357b35.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a33d7ffff&lt;br&gt;elapsed_seconds: 46.551
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_fb540531f051787c6f50f4f75a1fa0be = L.polygon(
#                 [[40.01386717429727, -105.27637934149125]

# %% [markdown]
# ## 🧭 Finding the hexes that were traveled across.

# %%
prev_hex_col = f"prev_{hex_col}"

trips_with_hex = (
    trips.with_columns(pl.col(hex_col).shift(1).over("trip_id").alias(prev_hex_col))
    .filter(pl.col("elapsed_seconds") <= FIFTEEN_MINUTES)
    .rename({"timestamp": "end", hex_col: "end_hex", prev_hex_col: "start_hex"})
    .with_columns(
        [
            (pl.col("end") - pl.duration(seconds=pl.col("elapsed_seconds"))).alias(
                "start"
            ),
            plh3.grid_path_cells(pl.col("start_hex"), pl.col("end_hex")).alias("path"),
        ]
    )
    .drop(["start_hex", "end_hex", "lat", "long"])
    .sort(["trip_id", "start"])
    .select(
        [
            "user_id",
            "trip_id",
            "start",
            "end",
            "elapsed_seconds",
            "path",
        ]
    )
)

# we now hav a dataframe with hex
display(trips_with_hex.head())
# Out:
# shape: (5, 6)
# ┌─────────┬──────────┬───────────────────┬───────────────────┬─────────────────┬───────────────────┐
# │ user_id ┆ trip_id  ┆ start             ┆ end               ┆ elapsed_seconds ┆ path              │
# │ ---     ┆ ---      ┆ ---               ┆ ---               ┆ ---             ┆ ---               │
# │ str     ┆ str      ┆ datetime[μs]      ┆ datetime[μs]      ┆ f64             ┆ list[str]         │
# ╞═════════╪══════════╪═══════════════════╪═══════════════════╪═════════════════╪═══════════════════╡
# │ sergey  ┆ sergey-0 ┆ 2024-12-16        ┆ 2024-12-16        ┆ 26.207          ┆ ["892681a306fffff │
# │         ┆          ┆ 02:51:12.171209   ┆ 02:51:38.171209   ┆                 ┆ "]                │
# │ sergey  ┆ sergey-0 ┆ 2024-12-16        ┆ 2024-12-16        ┆ 80.42           ┆ ["892681a306fffff │
# │         ┆          ┆ 02:51:38.591218   ┆ 02:52:58.591218   ┆                 ┆ ", "892681a33…    │
# │ sergey  ┆ sergey-0 ┆ 2024-12-16        ┆ 2024-12-16        ┆ 46.551          ┆ ["892681a33d3ffff │
# │         ┆          ┆ 02:52:59.142662   ┆ 02:53:45.142662   ┆                 ┆ ", "892681a33…    │
# │ sergey  ┆ sergey-0 ┆ 2024-12-16        ┆ 2024-12-16        ┆ 7.758           ┆ ["892681a33d7ffff │
# │         ┆          ┆ 02:53:45.901236   ┆ 02:53:52.901236   ┆                 ┆ "]                │
# │ sergey  ┆ sergey-0 ┆ 2024-12-16        ┆ 2024-12-16        ┆ 19.396          ┆ ["892681a33d7ffff │
# │         ┆          ┆ 02:53:53.297671   ┆ 02:54:12.297671   ┆                 ┆ "]                │
# └─────────┴──────────┴───────────────────┴───────────────────┴─────────────────┴───────────────────┘

# %% [markdown]
# ## ⏰ Figuring out time spent in each individual hexagon
#
# Currently, our hex data is a list. The next part of this is figuring out exactly how much time the user spent in each hexagon.  This is a non-trivial calculation because the user may be moving at different speeds at different points within the trip.

# %%
# This is not exactly needed, but it is more accurate to distribute time across hexas evenly.

trips_with_time_spent_in_hex = (
    trips_with_hex.sort(["trip_id", "start"])
    .with_columns(
        [
            # Get the length of the path
            pl.col("path").list.len().alias("path_length"),
        ]
    )
    .with_columns(
        [
            # Create a range of indices for the path
            pl.int_ranges(pl.lit(0), "path_length").alias("path_index"),
            # Calculate the time that should be allocated to each hexagon
            (pl.col("elapsed_seconds") / pl.col("path_length")).alias(
                "elapsed_seconds_per_hex"
            ),
        ]
    )
    .select(
        [
            "trip_id",
            "path",
            "end",
            "start",
            "path_index",
            "elapsed_seconds_per_hex",
        ]
    )
    .explode(["path", "path_index"])
    .with_columns(
        # We need to carefully allocate time to each hex.
        [
            # Calculate the end time for each hexagon
            (
                pl.col("start")
                + pl.duration(
                    seconds=(
                        pl.col("elapsed_seconds_per_hex") * (pl.col("path_index") + 1)
                    )
                )
            ).alias("end"),
            # Calculate the start time for each hexagon
            (
                pl.col("start")
                + pl.duration(
                    seconds=(pl.col("elapsed_seconds_per_hex") * pl.col("path_index"))
                )
            ).alias("start"),
        ]
    )
    # cleaning up the data
    .rename(
        {
            "path": hex_col,
            "elapsed_seconds_per_hex": "elapsed_seconds",
        }
    )
    .drop(["path_index"])
)


trips_with_time_spent_in_hex
# Out:
# shape: (1_158, 5)
# ┌──────────┬─────────────────┬─────────────────┬────────────────────────────┬─────────────────┐
# │ trip_id  ┆ hex9            ┆ end             ┆ start                      ┆ elapsed_seconds │
# │ ---      ┆ ---             ┆ ---             ┆ ---                        ┆ ---             │
# │ str      ┆ str             ┆ datetime[μs]    ┆ datetime[μs]               ┆ f64             │
# ╞══════════╪═════════════════╪═════════════════╪════════════════════════════╪═════════════════╡
# │ sergey-0 ┆ 892681a306fffff ┆ 2024-12-16      ┆ 2024-12-16 02:51:12.171209 ┆ 26.207          │
# │          ┆                 ┆ 02:51:38.171209 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a306fffff ┆ 2024-12-16      ┆ 2024-12-16 02:51:38.591218 ┆ 40.21           │
# │          ┆                 ┆ 02:52:18.591218 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33d3ffff ┆ 2024-12-16      ┆ 2024-12-16 02:52:18.591218 ┆ 40.21           │
# │          ┆                 ┆ 02:52:58.591218 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33d3ffff ┆ 2024-12-16      ┆ 2024-12-16 02:52:59.142662 ┆ 23.2755         │
# │          ┆                 ┆ 02:53:22.142662 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33d7ffff ┆ 2024-12-16      ┆ 2024-12-16 02:53:22.142662 ┆ 23.2755         │
# │          ┆                 ┆ 02:53:45.142662 ┆                            ┆                 │
# │ …        ┆ …               ┆ …               ┆ …                          ┆ …               │
# │ sergey-1 ┆ 89268162117ffff ┆ 2024-12-16      ┆ 2024-12-16 07:52:33.207001 ┆ 26.245          │
# │          ┆                 ┆ 07:52:59.207001 ┆                            ┆                 │
# │ sergey-1 ┆ 89268162117ffff ┆ 2024-12-16      ┆ 2024-12-16 07:52:59.978851 ┆ 4.771           │
# │          ┆                 ┆ 07:53:03.978851 ┆                            ┆                 │
# │ sergey-1 ┆ 89268162117ffff ┆ 2024-12-16      ┆ 2024-12-16 07:53:04.750701 ┆ 4.771           │
# │          ┆                 ┆ 07:53:08.750701 ┆                            ┆                 │
# │ sergey-1 ┆ 89268162117ffff ┆ 2024-12-16      ┆ 2024-12-16 07:53:09.452176 ┆ 16.701          │
# │          ┆                 ┆ 07:53:25.452176 ┆                            ┆                 │
# │ sergey-1 ┆ 89268162117ffff ┆ 2024-12-16      ┆ 2024-12-16 07:53:25.609951 ┆ 7.157           │
# │          ┆                 ┆ 07:53:32.609951 ┆                            ┆                 │
# └──────────┴─────────────────┴─────────────────┴────────────────────────────┴─────────────────┘

# %% [markdown]
# ## 🎁 Cleaning up the final data

# %%
# There's a lot of repeated hexes, so let's go ahead and aggregate that.

final_df = trips_with_time_spent_in_hex.group_by(
    ["trip_id", hex_col],
    maintain_order=True,
).agg(
    [
        pl.col("end").max(),
        pl.col("start").min(),
        pl.col("elapsed_seconds").sum(),
    ],
)

display(final_df.head())
# Out:
# shape: (5, 5)
# ┌──────────┬─────────────────┬─────────────────┬────────────────────────────┬─────────────────┐
# │ trip_id  ┆ hex9            ┆ end             ┆ start                      ┆ elapsed_seconds │
# │ ---      ┆ ---             ┆ ---             ┆ ---                        ┆ ---             │
# │ str      ┆ str             ┆ datetime[μs]    ┆ datetime[μs]               ┆ f64             │
# ╞══════════╪═════════════════╪═════════════════╪════════════════════════════╪═════════════════╡
# │ sergey-0 ┆ 892681a306fffff ┆ 2024-12-16      ┆ 2024-12-16 02:51:12.171209 ┆ 66.417          │
# │          ┆                 ┆ 02:52:18.591218 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33d3ffff ┆ 2024-12-16      ┆ 2024-12-16 02:52:18.591218 ┆ 63.4855         │
# │          ┆                 ┆ 02:53:22.142662 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33d7ffff ┆ 2024-12-16      ┆ 2024-12-16 02:53:22.142662 ┆ 71.7655         │
# │          ┆                 ┆ 02:54:33.969828 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a33c7ffff ┆ 2024-12-16      ┆ 2024-12-16 02:54:33.969828 ┆ 40.732          │
# │          ┆                 ┆ 02:55:14.762698 ┆                            ┆                 │
# │ sergey-0 ┆ 892681a331bffff ┆ 2024-12-16      ┆ 2024-12-16 02:55:14.762698 ┆ 31.0335         │
# │          ┆                 ┆ 02:55:45.038420 ┆                            ┆                 │
# └──────────┴─────────────────┴─────────────────┴────────────────────────────┴─────────────────┘

# %% [markdown]
# ## Let's try visualizing

# %%
# Notice how there's no gaps and we can see the time spent in each hexagon.
hex_map = plh3.graphing.plot_hex_fills(
    trips_with_time_spent_in_hex, hex_id_col=hex_col, metric_col="elapsed_seconds"
)
display(hex_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57e4eef7f42e0c2e1d19a580ad077e92 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57e4eef7f42e0c2e1d19a580ad077e92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57e4eef7f42e0c2e1d19a580ad077e92 = L.map(
#                 &quot;map_57e4eef7f42e0c2e1d19a580ad077e92&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08e897d124a9663e9ebc652b3545181b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08e897d124a9663e9ebc652b3545181b.addTo(map_57e4eef7f42e0c2e1d19a580ad077e92);
#
#
#             var polygon_126f9be7e12e9290972115edca0b38d4 = L.polygon(
#                 [[40.017049457282525, -105.2760371821852], [40.018555636775524, -105.27462138937283], [40.02023163980317, -105.2756950016612], [40.02040145230899, -105.27818446236408], [40.018895254588266, -105.27960023471259], [40.017219262589784, -105.27852656682553]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f58b46&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f58b46&quot;, &quot;fillOpacity&quot;: 0.8901193586093532, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_57e4eef7f42e0c2e1d19a580ad077e92);
#
#
#             polygon_126f9be7e12e9290972115edca0b38d4.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a306fffff&lt;br&gt;elapsed_seconds: 26.207
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_15e0fc4cf4eab56dd756c4fd605a4f5e = L.polygon(
#                 [[40.017049457282525, -105.2760371821852], [40.018555636775524, -105.27462138937283], [40.02023163980317, -105.2756950016612], [40.02040145230899, -105.27818446236408], [40.018895254588266, -105.27960023471259], [40.017219262589784, -105.27852656682553]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fdb52d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fdb52d&quot;, &quot;fillOpacity&quot;: 0.935242936297364, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_57e4eef7f42e0c2e1d19a580ad077e92);
#
#
#             polygon_15e0fc4cf4eab56dd756c4fd605a4f5e.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a306fffff&lt;br&gt;elapsed_seconds: 40.21
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_3d8615e4e0ef554247385063c4d5b972 = L.polygon(
#                 [[40.01571301103724, -105.27994229053606], [40.017219262589784, -105.27852656682553], [40.018895254588266, -105.27960023471259], [40.01906498400045, -105.28208968189972], [40.01755871422176, -105.28350538513264], [40.01588273325735, -105.28243166165943]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fdb52d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fdb52d&quot;, &quot;fillOpacity&quot;: 0.935242936297364, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_57e4eef7f42e0c2e1d19a580ad077e92);
#
#
#             polygon_3d8615e4e0ef554247385063c4d5b972.bindTooltip(
#                 `&lt;div&gt;
#                      Hex: 892681a33d3ffff&lt;br&gt;elapsed_seconds: 40.21
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var polygon_d044f048771d81cc5ca67debd08efe48 = L.polygon(
#                 [[40.01571301103724, -105.27994229053606],
